# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Indeed

# %% [markdown]
# #### Create Skills Dictionary

# %%
skills_keywords_dict = {
                            # tech skills
                            'Excel': ['Excel'],
                            'Python': ['Python'],
                            'R': ['R ', ' R ', 'R,', 'R/'], # 'R' surrounded by spaces and signs
                            'Ruby': ['Ruby'],
                            'Java/Scala': ['Java', 'JVM', 'Scala'],
                            'C/C++': ['C/C++', 'C++', ' C '],   # 'C' surrounded by spaces and signs
                            'MATLAB': ['MATLAB'],
                            'SAS': ['SAS'],
                            'SQL/databases': ['SQL', 'databases'],
                            'SPSS': ['SPSS'],
                            'Stata': ['Stata'],
                            'RapidMiner': ['RapidMiner', 'Rapid Miner'],
                            'Machine Learning': ['Machine Learning', 'ML'],
                            'Data Mining/Analytics': ['Data Mining', 'DM', 'Analytics'],
                            'NLP': ['Natural Language Processing', 'NLP'],
                            'Visualisation': ['Visualisation', 'Visualization'],
                            'Big Data': ['Big Data', 'Spark', 'kafka', 'Hive', 
                                         'beam', 'Hadoop', 'MapReduce', 'Hbase'],
                            'Cloud': ['Cloud', 'AWS', 'GCP', 'Azure ', 'Google Cloud'],
                            'REST': ['REST', 'flask', 'Sinatra'],
                            'Math': ['Algebra', 'Statistics', 'Operations research'],
                            'DevOps': ['DevOps', 'TDD', 'test-driven', 'GitHub'],  
                            
                            # soft skills
                            'communication': ['communication', 'presentation', 'team player'],
                            'problem solving': ['problem solving'],
                            'project_management': ['project management'],
                            'leadership': ['leadership'],
                            'consulting': ['consulting'],
                            'French':['french', 'French']
                        }

# %% [markdown]
# #### Get urls from Indeed pages

# %%
# 20 job postings per page
def get_urls(url):
    # get html back
    html = requests.get(url)
    html = html.text
    soup = BeautifulSoup(html, 'lxml')

    # extract the number of search results
    nums = soup.find('div', {'id':'searchCount'}).text
    nums = int(nums.split()[3])

    # add the common part between all search pages
    base_url = "https://www.indeed.ca" + soup.find('div', {'class': 'pagination'}).find('a').get('href')[:-2]
    
    urls = []
    urls.append(base_url)
    for i in range(20, nums, 20):
        urls.append(base_url + str(i))
    
    return urls, nums

# %%
url = 'https://ca.indeed.com/jobs?q=Data+scientist&l=Canada'
urls, nums = get_urls(url)

# %% [markdown]
# #### Get link for each job and its html text

# %%
def get_job_links_info(urls):
    
    dic = {}
    # loop over all page-urls
    for page_url in urls:

        # get the HTML of the search results page
        page = requests.get(page_url)
        content = page.text
        soup = BeautifulSoup(content, 'lxml')

        # find all <div> tags containing each job posting links and feed them to the function 'scrape_job_info'
        results = soup.find_all('div',{'class': 'title'})

        for job in results:

            job_link = "https://www.indeed.ca" + job.find('a')['href']

            job_page = requests.get(job_link)
            job_content = job_page.text
            #soup_job = BeautifulSoup(job_content,'lxml')
            #job_desc = soup_job.find('div',{'class':"jobsearch-jobDescriptionText"}).get_text()
            dic[job_link] = job_content
            
    return dic

# %%
info_dict = get_job_links_info(urls)

# %% [markdown]
# #### Get job_title, company_name, skills from info_dict

# %%
def get_skills_from_job(jobs_dict, skills_dict):
    
    results_dict = {} 
    
    # loop over all key(link)-value(HTML code) pairs in scraping results
    for link, job_html_text in jobs_dict.items():
        
    
        soup_job = BeautifulSoup(job_html_text, 'lxml')
        
        results_dict[link] = {} 
        
        # extract job title
        try:
            results_dict[link]['job_title'] = soup_job.find('h3', 
                                {'class':"icl-u-xs-mb--xs icl-u-xs-mt--none jobsearch-JobInfoHeader-title"}).text   
        except IndexError:
            results_dict[link]['job_title'] = 'Not found'
            
         # extract company name
        try:
            results_dict[link]['company_name'] = soup_job.find('div', 
                                                                   {'class': 'icl-u-lg-mr--sm icl-u-xs-mr--xs'}).text 
        except IndexError:
            results_dict[link]['company_name'] = 'Not found'
                
        # search for the skills
        job_text = soup_job.text
        for skill_category, skills in skills_dict.items():
            
            category_found = 0  
            
            for skill in skills:        
                if job_text.find(skill) != -1: 
                    
                    category_found = 1
            
            results_dict[link][skill_category] = category_found 
    
    return results_dict

# %%
results_dict = get_skills_from_job(info_dict, skills_keywords_dict)
df_indeed = pd.DataFrame(results_dict).T.reset_index()

# %%
df_indeed.to_csv('indeed.csv')

# %% [markdown]
# #### Indeed Example

# %%
page = requests.get('https://www.indeed.ca/jobs?q=Data+scientist&l=Canada&start=')
content = page.text
soup = BeautifulSoup(content, 'lxml')
results = soup.find('div',{'class': 'title'})
job_link = "https://www.indeed.ca" + results.find('a')['href']
job_page = requests.get(job_link)
job_content = job_page.text
soup_job = BeautifulSoup(job_content,'lxml')

# %%
results
# Out:
# <div class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0C7nhuITA1a93dL10dRXTH-RWH4RI4W-baytkusaUeAAtxqSbyONvqD9s0vYo9ZxE_9vfJLiITbWzk-Pd151amlv55zjMAkwFeNXHITobkC5eC1P_i6lXxPblHcR4s7r0pe5I91O5yExkfzKL5XLO0ugsW7oT3uoMzYmm9rvHQYcfeL33EVcawW4SA8oZIkQ8Ep-2yiXMJYAlwsEIErIRGpdaWr-uYCaXfmJhXBxTbP-JC3qixjZuoI4chnN3ma4eBKwXMTZRha8FaynAnnXCJVJ6D7ttZNRgJx0HFmecSM6NtcXaqTZIIbcAmsI2U5_lOGyaxEwxRCs1AwGYPXX7-2ZTQwBIJGBH6E3N34rAe2QuV_lAoEgjhAcl0LRUQD5jQN7Yr8YMjR8vCNySoWIR7Jc-jCAlToG3cM0L9mtO3QgC9Zzbtf3t3I2uwFXWX9ymfCsmYe9BijN2tLMtBHg0hL&amp;p=0&amp;fvj=1&amp;vjs=3" id="sja0" onclick="setRefineByCookie([]); sjoc('sja0', 1); convCtr('SJ'); rclk(this,jobmap[0],true,1);" onmousedown="sjomd('sja0'); clk('sja0'); rclk(this,jobmap[0],1);" rel="noopener nofollow" target="_blank" title="Data Scientist with Backend Experience">
# Data <b>Scientist</b> with Backend Experience</a>
# </div>

# %%
soup.find('div', {'class': 'pagination'}).find('a').get('href')[:-2]
# Out:
# '/jobs?q=Data+scientist&l=Canada&start='

# %%
soup_job.find('h3', {'class' : 'icl-u-xs-mb--xs icl-u-xs-mt--none jobsearch-JobInfoHeader-title'}).text
# Out:
# 'Data Scientist with Backend Experience'

# %%
soup_job.find('div',{'class':"icl-u-lg-mr--sm icl-u-xs-mr--xs"}).text
# Out:
# 'Buy With Impact'

# %%
soup_job.text.find('SQL') != -1
# Out:
# True

# %% [markdown]
# # Linkedin

# %%
# 20 job postings per page
def get_urls_linkedin(url):
    # get html back
    html = requests.get(url)
    html = html.text
    soup = BeautifulSoup(html, 'lxml')

    # extract the number of search results
    nums = soup.find('h1').find('span').text
    nums = int(nums)

    # add the common part between all search pages
    base_url = 'https://ca.linkedin.com/jobs/data-scientist-jobs?position=1&pageNum='
    
    urls = []
    for i in range(0, nums, 25):
        urls.append(base_url + str(i))
    
    return urls, nums

# %%
url = "https://ca.linkedin.com/jobs/data-scientist-jobs"
urls,nums = get_urls_linkedin(url)

# %%
def get_job_links_info_linkedin(urls):
    
    dic = {}
    # loop over all page-urls
    for page_url in urls:

        # get the HTML of the search results page
        page = requests.get(page_url)
        content = page.text
        soup = BeautifulSoup(content, 'lxml')

        # find all <div> tags containing each job posting links and feed them to the function 'scrape_job_info'
        results = soup.find_all('a',{'class':"result-card__full-card-link"})

        for job in results:

            job_link = job['href']

            job_page = requests.get(job_link)
            job_content = job_page.text
            #soup_job = BeautifulSoup(job_content,'lxml')
            #job_desc = soup_job.find('div',{'class':"jobsearch-jobDescriptionText"}).get_text()
            dic[job_link] = job_content
            
    return dic

# %%
linkedin_dict = get_job_links_info_linkedin(urls)

# %%
len(linkedin_dict)
# Out:
# 825

# %%
def get_skills_from_job_linkedin(jobs_dict, skills_dict):
    
    results_dict = {} 
    
    # loop over all key(link)-value(HTML code) pairs in scraping results
    for link, job_html_text in jobs_dict.items():
        
    
        soup_job = BeautifulSoup(job_html_text, 'lxml')
        
        results_dict[link] = {} 
        
        # extract job title
        try:
            results_dict[link]['job_title'] = soup_job.find('h1',{'class':'topcard__title'}).text   
        except IndexError:
            results_dict[link]['job_title'] = 'Not found'
            
         # extract company name
        try:
            results_dict[link]['company_name'] = soup_job.find('a',{'class':'topcard__org-name-link topcard__flavor--black-link'}).text
        except AttributeError:
            results_dict[link]['company_name'] = soup_job.find('span',{'class':'topcard__flavor'}).text
                
        # search for the skills
        job_text = soup_job.text
        for skill_category, skills in skills_dict.items():
            
            category_found = 0  
            
            for skill in skills:        
                if job_text.find(skill) != -1: 
                    
                    category_found = 1
            
            results_dict[link][skill_category] = category_found 
    
    return results_dict

# %%
results_dict = get_skills_from_job_linkedin(linkedin_dict, skills_keywords_dict)
df_linkedin = pd.DataFrame(results_dict).T.reset_index()

# %%
df_linkedin.to_csv('linkedin.csv')

# %% [markdown]
# #### Linkedin Example

# %%
url = "https://ca.linkedin.com/jobs/data-scientist-jobs"
html = requests.get(url)
html = html.text
soup = BeautifulSoup(html, 'lxml')

# extract the number of search results
soup.find('h1').find('span').text
# Out:
# '805'

# %%
job_link = soup.find('a',{'class':"result-card__full-card-link"})['href']

# %%
job_page = requests.get(job_link)
job_content = job_page.text
soup_job = BeautifulSoup(job_content,'lxml')

# %%
soup_job.find('h1',{'class':'topcard__title'}).text
# Out:
# 'Data Scientist'

# %%
soup_job.find('a',{'class':'topcard__org-name-link topcard__flavor--black-link'}).text
# Out:
# 'Visa'

# %% [markdown]
# # Coursera

# %% [markdown]
# #### Data Science with Python 5

# %%
url = 'https://www.coursera.org/specializations/data-science-python#courses'
html = requests.get(url)
html = html.text
soup = BeautifulSoup(html, 'lxml')

# %%
a = soup.find_all('div',{'class':'Row_nvwp6p CourseItem'})
links = []
for b in a:
    links.append('https://www.coursera.org' + b.find('a',{'data-e2e':"course-link"})['href'])
links.append('https://www.coursera.org/learn/python-social-network-analysis')

# %% [markdown]
# #### IBM data science 9

# %%
url = 'https://www.coursera.org/professional-certificates/ibm-data-science#courses'
html = requests.get(url)
html = html.text
soup = BeautifulSoup(html, 'lxml')

# %%
a = soup.find_all('div',{'class':'Row_nvwp6p CourseItem'})
for b in a:
    links.append('https://www.coursera.org' + b.find('a',{'data-e2e':"course-link"})['href'])
links.append('https://www.coursera.org/learn/sql-data-science')
links.append('https://www.coursera.org/learn/data-analysis-with-python')
links.append('https://www.coursera.org/learn/python-for-data-visualization')
links.append('https://www.coursera.org/learn/machine-learning-with-python')
links.append('https://www.coursera.org/learn/applied-data-science-capstone')

# %% [markdown]
# #### Data Science Specialization (John Hopkins) 10

# %%
url = 'https://www.coursera.org/specializations/jhu-data-science'
html = requests.get(url)
html = html.text
soup = BeautifulSoup(html, 'lxml')

# %%
a = soup.find_all('div',{'class':'Row_nvwp6p CourseItem'})
for b in a:
    links.append('https://www.coursera.org' + b.find('a',{'data-e2e':"course-link"})['href'])
links.append('https://www.coursera.org/learn/reproducible-research')
links.append('https://www.coursera.org/learn/statistical-inference')
links.append('https://www.coursera.org/learn/regression-models')
links.append('https://www.coursera.org/learn/practical-machine-learning')
links.append('https://www.coursera.org/learn/data-products')
links.append('https://www.coursera.org/learn/data-science-project')

# %% [markdown]
# #### Data Science: Statistics and Machine Learning Specialization (John Hopkins) 5

# %%
url = 'https://www.coursera.org/specializations/data-science-statistics-machine-learning'
html = requests.get(url)
html = html.text
soup = BeautifulSoup(html, 'lxml')

# %%
a = soup.find_all('div',{'class':'Row_nvwp6p CourseItem'})
for b in a:
    links.append('https://www.coursera.org' + b.find('a',{'data-e2e':"course-link"})['href'])
links.append('https://www.coursera.org/learn/data-science-project')

# %% [markdown]
# #### Data Engineering, Big Data, and Machine Learning on GCP (Google) 5

# %%
url = 'https://www.coursera.org/specializations/data-science-statistics-machine-learning'
html = requests.get(url)
html = html.text
soup = BeautifulSoup(html, 'lxml')

# %%
a = soup.find_all('div',{'class':'Row_nvwp6p CourseItem'})
for b in a:
    links.append('https://www.coursera.org' + b.find('a',{'data-e2e':"course-link"})['href'])
links.append('https://www.coursera.org/learn/smart-analytics-machine-learning-ai-gcp')

# %% [markdown]
# #### Advanced Data Science with IBM 4

# %%
url = 'https://www.coursera.org/specializations/advanced-data-science-ibm'
html = requests.get(url)
html = html.text
soup = BeautifulSoup(html, 'lxml')

# %%
a = soup.find_all('div',{'class':'Row_nvwp6p CourseItem'})
for b in a:
    links.append('https://www.coursera.org' + b.find('a',{'data-e2e':"course-link"})['href'])

# %% [markdown]
# ## Get course names and descriptions

# %%
course_names = []
for course_link in links:
    course_html = requests.get(course_link)
    course_html = course_html.text
    course_soup = BeautifulSoup(course_html, 'lxml')
    name = course_soup.find('h1').text
    course_names.append(name)

# %%
descs = []
for course_link in links:
    course_html = requests.get(course_link)
    course_html = course_html.text
    course_soup = BeautifulSoup(course_html, 'lxml')
    desc = course_soup.find('div',{'class':'content-inner'}).text
    descs.append(desc)

# %%
df_coursera = pd.DataFrame({'Course Names':course_names,'Course Description':descs})

# %%
df_coursera
# Out:
#                                          Course Names  \
# 0              Introduction to Data Science in Python
# 1   Applied Plotting, Charting & Data Representati...
# 2                  Applied Machine Learning in Python
# 3                       Applied Text Mining in Python
# 4           Applied Social Network Analysis in Python
# 5                              What is Data Science?
# 6                  Open Source tools for Data Science
# 7                            Data Science Methodology
# 8                      Python for Data Science and AI
# 9                  Databases and SQL for Data Science
# 10                          Data Analysis with Python
# 11                     Data Visualization with Python
# 12                       Machine Learning with Python
# 13                      Applied Data Science Capstone
# 14                     The Data Scientistâs Toolbox
# 15                                      R Programming
# 16                          Getting and Cleaning Data
# 17                          Exploratory Data Analysis
# 18                              Reproducible Research
# 19                              Statistical Inference
# 20                                  Regression Models
# 21                         Practical Machine Learning
# 22                           Developing Data Products
# 23                              Data Science Capstone
# 24                              Statistical Inference
# 25                                  Regression Models
# 26                         Practical Machine Learning
# 27                           Developing Data Products
# 28                              Data Science Capstone
# 29                              Statistical Inference
# 30                                  Regression Models
# 31                         Practical Machine Learning
# 32                           Developing Data Products
# 33   Smart Analytics, Machine Learning, and AI on GCP
# 34              Fundamentals of Scalable Data Science
# 35    Advanced Machine Learning and Signal Processing
# 36                       Applied AI with DeepLearning
# 37                     Advanced Data Science Capstone
#
#                                    Course Description
# 0   This course will introduce the learner to the ...
# 1   This course will introduce the learner to info...
# 2   This course will introduce the learner to appl...
# 3   This course will introduce the learner to text...
# 4   This course will introduce the learner to netw...
# 5   The art of uncovering the insights and trends ...
# 6   What are some of the most popular data science...
# 7   Despite the recent increase in computing power...
# 8   This introduction to Python will kickstart you...
# 9   Much of the world's data resides in databases....
# 10  Learn how to analyze data using Python. This c...
# 11  "A picture is worth a thousand words". We are ...
# 12  This course dives into the basics of machine l...
# 13  This capstone project course will give you a t...
# 14  In this course you will get an introduction to...
# 15  In this course you will learn how to program i...
# 16  Before you can work with data you have to get ...
# 17  This course covers the essential exploratory t...
# 18  This course focuses on the concepts and tools ...
# 19  Statistical inference is the process of drawin...
# 20  Linear models, as their name implies, relates ...
# 21  One of the most common tasks performed by data...
# 22  A data product is the production output from a...
# 23  The capstone project class will allow students...
# 24  Statistical inference is the process of drawin...
# 25  Linear models, as their name implies, relates ...
# 26  One of the most common tasks performed by data...
# 27  A data product is the production output from a...
# 28  The capstone project class will allow students...
# 29  Statistical inference is the process of drawin...
# 30  Linear models, as their name implies, relates ...
# 31  One of the most common tasks performed by data...
# 32  A data product is the production output from a...
# 33  Incorporating machine learning into data pipel...
# 34  Apache Spark is the de-facto standard for larg...
# 35  >>> By enrolling in this course you agree to t...
# 36  >>> By enrolling in this course you agree to t...
# 37  This project completer has proven a deep under...

# %%
df_coursera.insert(0, 'Specialization Names', '')

# %%
df_coursera.iloc[:5,0] = 'Data Science with Python (UoM)'
df_coursera.iloc[5:14,0] = 'IBM Data Science'
df_coursera.iloc[14:24,0] = 'Data Science (JHU)'
df_coursera.iloc[24:29,0] = 'Data Science: Statistics and Machine Learning Specialization (JHU)'
df_coursera.iloc[29:34,0] = 'Data Engineering, Big Data, and Machine Learning on GCP (Google)'
df_coursera.iloc[34:,0] = 'Advanced Data Science with IBM'

# %%
df_coursera
# Out:
#                                  Specialization Names  \
# 0                      Data Science with Python (UoM)
# 1                      Data Science with Python (UoM)
# 2                      Data Science with Python (UoM)
# 3                      Data Science with Python (UoM)
# 4                      Data Science with Python (UoM)
# 5                                    IBM Data Science
# 6                                    IBM Data Science
# 7                                    IBM Data Science
# 8                                    IBM Data Science
# 9                                    IBM Data Science
# 10                                   IBM Data Science
# 11                                   IBM Data Science
# 12                                   IBM Data Science
# 13                                   IBM Data Science
# 14                                 Data Science (JHU)
# 15                                 Data Science (JHU)
# 16                                 Data Science (JHU)
# 17                                 Data Science (JHU)
# 18                                 Data Science (JHU)
# 19                                 Data Science (JHU)
# 20                                 Data Science (JHU)
# 21                                 Data Science (JHU)
# 22                                 Data Science (JHU)
# 23                                 Data Science (JHU)
# 24  Data Science: Statistics and Machine Learning ...
# 25  Data Science: Statistics and Machine Learning ...
# 26  Data Science: Statistics and Machine Learning ...
# 27  Data Science: Statistics and Machine Learning ...
# 28  Data Science: Statistics and Machine Learning ...
# 29  Data Engineering, Big Data, and Machine Learni...
# 30  Data Engineering, Big Data, and Machine Learni...
# 31  Data Engineering, Big Data, and Machine Learni...
# 32  Data Engineering, Big Data, and Machine Learni...
# 33  Data Engineering, Big Data, and Machine Learni...
# 34                     Advanced Data Science with IBM
# 35                     Advanced Data Science with IBM
# 36                     Advanced Data Science with IBM
# 37                     Advanced Data Science with IBM
#
#                                          Course Names  \
# 0              Introduction to Data Science in Python
# 1   Applied Plotting, Charting & Data Representati...
# 2                  Applied Machine Learning in Python
# 3                       Applied Text Mining in Python
# 4           Applied Social Network Analysis in Python
# 5                              What is Data Science?
# 6                  Open Source tools for Data Science
# 7                            Data Science Methodology
# 8                      Python for Data Science and AI
# 9                  Databases and SQL for Data Science
# 10                          Data Analysis with Python
# 11                     Data Visualization with Python
# 12                       Machine Learning with Python
# 13                      Applied Data Science Capstone
# 14                     The Data Scientistâs Toolbox
# 15                                      R Programming
# 16                          Getting and Cleaning Data
# 17                          Exploratory Data Analysis
# 18                              Reproducible Research
# 19                              Statistical Inference
# 20                                  Regression Models
# 21                         Practical Machine Learning
# 22                           Developing Data Products
# 23                              Data Science Capstone
# 24                              Statistical Inference
# 25                                  Regression Models
# 26                         Practical Machine Learning
# 27                           Developing Data Products
# 28                              Data Science Capstone
# 29                              Statistical Inference
# 30                                  Regression Models
# 31                         Practical Machine Learning
# 32                           Developing Data Products
# 33   Smart Analytics, Machine Learning, and AI on GCP
# 34              Fundamentals of Scalable Data Science
# 35    Advanced Machine Learning and Signal Processing
# 36                       Applied AI with DeepLearning
# 37                     Advanced Data Science Capstone
#
#                                    Course Description
# 0   This course will introduce the learner to the ...
# 1   This course will introduce the learner to info...
# 2   This course will introduce the learner to appl...
# 3   This course will introduce the learner to text...
# 4   This course will introduce the learner to netw...
# 5   The art of uncovering the insights and trends ...
# 6   What are some of the most popular data science...
# 7   Despite the recent increase in computing power...
# 8   This introduction to Python will kickstart you...
# 9   Much of the world's data resides in databases....
# 10  Learn how to analyze data using Python. This c...
# 11  "A picture is worth a thousand words". We are ...
# 12  This course dives into the basics of machine l...
# 13  This capstone project course will give you a t...
# 14  In this course you will get an introduction to...
# 15  In this course you will learn how to program i...
# 16  Before you can work with data you have to get ...
# 17  This course covers the essential exploratory t...
# 18  This course focuses on the concepts and tools ...
# 19  Statistical inference is the process of drawin...
# 20  Linear models, as their name implies, relates ...
# 21  One of the most common tasks performed by data...
# 22  A data product is the production output from a...
# 23  The capstone project class will allow students...
# 24  Statistical inference is the process of drawin...
# 25  Linear models, as their name implies, relates ...
# 26  One of the most common tasks performed by data...
# 27  A data product is the production output from a...
# 28  The capstone project class will allow students...
# 29  Statistical inference is the process of drawin...
# 30  Linear models, as their name implies, relates ...
# 31  One of the most common tasks performed by data...
# 32  A data product is the production output from a...
# 33  Incorporating machine learning into data pipel...
# 34  Apache Spark is the de-facto standard for larg...
# 35  >>> By enrolling in this course you agree to t...
# 36  >>> By enrolling in this course you agree to t...
# 37  This project completer has proven a deep under...

# %%
df_coursera.to_csv('coursera.csv')

# %% [markdown]
# # Datacamp

# %%
url = 'https://www.datacamp.com/search?q=Data%20Science'
html = requests.get(url)
html = html.text
soup = BeautifulSoup(html, 'lxml')

# %%
a = soup.find_all('a',{'class':"shim ds-snowplow-search-v2-result-course"})
links_dc = []
for b in a:
    links_dc.append('https://www.datacamp.com' + b['href'])

# %%
course_html = requests.get(links_dc[1])
course_html = course_html.text
course_soup = BeautifulSoup(course_html, 'lxml')

# %%
course_soup.find('p',{'class':'course__description'}).text
# Out:
# "What is data science and how can you use it to strengthen your organization? This course will teach you about the skills you need on your data team, and how you can structure that team to meet your organization's needs. Data is everywhere! This course will provide you with an understanding of data sources your company can use and how to store that data. You'll also discover ways to analyze and visualize your data through dashboards and A/B tests. To wrap up the course, we'll discuss exciting topics in machine learning, including clustering, time series prediction, natural language processing (NLP), deep learning, and explainable AI! Along the way, you'll learn about a variety of real-world applications of data science and gain a better understanding of these concepts through practical exercises."

# %%
list(set(course_soup.find_all('h4',{'class':'chapter__title'})))
# Out:
# [<h4 class="chapter__title">
#            Introduction to Data Science
#          </h4>, <h4 class="chapter__title">
#            Data Collection and Storage
#          </h4>, <h4 class="chapter__title">
#            Prediction
#          </h4>, <h4 class="chapter__title">
#            Analysis and Visualization
#          </h4>]

# %%
list(set(course_soup.find_all('p',{'class':'chapter__description dc-u-fxi-fg-1 dc-u-pr-24 dc-u-pl-24 dc-u-mb-18'})))
# Out:
# [<p class="chapter__description dc-u-fxi-fg-1 dc-u-pr-24 dc-u-pl-24 dc-u-mb-18">
#      We'll start the course by defining what data science is. We'll cover the data science workflow, and how data science is applied to real-world business problems. We'll finish the chapter by learning about ways to structure your data team to meet your organization's needs.
#    </p>,
#  <p class="chapter__description dc-u-fxi-fg-1 dc-u-pr-24 dc-u-pl-24 dc-u-mb-18">
#      In this chapter, we'll discuss ways to explore and visualize data through dashboards. We'll discuss the elements of a dashboard and how to make a directed request for a dashboard. This chapter will also cover making ad hoc data requests and A/B tests, which are a powerful analytics tool that de-risk decision-making.
#    </p>,
#  <p class="chapter__description dc-u-fxi-fg-1 dc-u-pr-24 dc-u-pl-24 dc-u-mb-18">
#      In this final chapter, we'll discuss the buzziest topic in data science: machine learning! We'll cover supervised and unsupervised machine learning, and clustering. Then, we'll move on to special topics in machine learning, including time series prediction, natural language processing, deep learning, and explainable AI!
#    </p>,
#  <p class="chapter__description dc-u-fxi-fg-1 dc-u-pr-24 dc-u-pl-24 dc-u-mb-18">
#      Now that we understand the data science workflow, we'll dive deeper into the first step: data collection. We'll learn about the different data sources your company can draw from, and how to store that data once it's collected.
#    </p>]

# %%
course_soup.find('h1').text
# Out:
# 'Data Science for Business'

# %%
course_names,chapter_num = [],[]
for course_link in links_dc:
    course_html = requests.get(course_link)
    course_html = course_html.text
    course_soup = BeautifulSoup(course_html, 'lxml')
    name = course_soup.find('h1').text
    num = len(set(course_soup.find_all('h4',{'class':'chapter__title'})))
    course_names.append(name)
    chapter_num.append(num)

# %%
course_descs = []
for course_link in links_dc:
    course_html = requests.get(course_link)
    course_html = course_html.text
    course_soup = BeautifulSoup(course_html, 'lxml')
    try:
        desc = course_soup.find('p',{'class':'course__description'}).text
    except:
        desc = "No Description"
    course_descs.append(desc)

# %%
df_dc_courses = pd.DataFrame({'Course Names':course_names,'Number of Chapters':chapter_num,'Course Description':course_descs})
df_dc_courses
# Out:
#                                          Course Names  Number of Chapters  \
# 0                           Data Science for Everyone                   4
# 1                           Data Science for Business                   4
# 2                Python Data Science Toolbox (Part 1)                   3
# 3                Python Data Science Toolbox (Part 2)                   3
# 4              Introduction to Data Science in Python                   4
# 5               Data Types for Data Science in Python                   5
# 6             Unit Testing for Data Science in Python                   4
# 7                Linear Algebra for Data Science in R                   4
# 8                                 Intermediate Python                   5
# 9            Analyzing Election and Polling Data in R                   4
# 10                      Data Manipulation with pandas                   4
# 11      Machine Learning for Marketing Analytics in R                   4
# 12                Creating Robust Workflows in Python                   4
# 13  Software Engineering for Data Scientists in Py...                   4
# 14                                   Intermediate SQL                   4
# 15             Working with Geospatial Data in Python                   4
# 16                  Nonlinear Modeling in R with GAMs                   4
# 17        Fundamentals of Bayesian Data Analysis in R                   5
# 18                      Introduction to the Tidyverse                   4
# 19  Case Study: School Budgeting with Machine Lear...                   4
# 20                            Joining Data with dplyr                   4
# 21                            Cleaning Data in Python                   5
# 22                        Optimizing R Code with Rcpp                   4
# 23             Winning a Kaggle Competition in Python                   4
# 24             Building Dashboards with flexdashboard                   4
# 25          Analyzing Marketing Campaigns with pandas                   4
# 26                              Cluster Analysis in R                   4
# 27       Improving Your Data Visualizations in Python                   4
# 28      Building and Distributing Packages with Conda                   3
# 29    Importing and Managing Financial Data in Python                   4
# 30             Visualizing Time Series Data in Python                   5
# 31              String Manipulation with stringr in R                   5
# 32           Parallel Programming with Dask in Python                   5
# 33                             Introduction to Python                   0
# 34                                Joining Data in SQL                   4
# 35                            Python for MATLAB Users                   4
# 36                  Visualization Best Practices in R                   4
# 37                                 pandas Foundations                   4
# 38            Building Dashboards with shinydashboard                   4
# 39                             Web Scraping in Python                   4
# 40       Intermediate Data Visualization with Seaborn                   4
# 41          Interactive Data Visualization with Bokeh                   4
# 42                                    R For SAS Users                   4
# 43   Introduction to Natural Language Processing in R                   4
# 44     Designing Machine Learning Workflows in Python                   4
# 45                     Generalized Linear Models in R                   4
# 46                   Machine Learning with caret in R                   5
# 47             Extreme Gradient Boosting with XGBoost                   4
# 48             Introduction to Writing Functions in R                   4
# 49                                  Introduction to R                   0
#
#                                    Course Description
# 0   What is data science, why is it so popular, an...
# 1   What is data science and how can you use it to...
# 2   It's time to push forward and develop your Pyt...
# 3   In this second Python Data Science Toolbox cou...
# 4   Begin your journey into Data Science! Even if ...
# 5   Have you got your basic Python programming cho...
# 6   Every data science project needs unit testing....
# 7   Linear algebra is one of the most important se...
# 8   Learning Python is crucial for any aspiring da...
# 9   This is an introductory course to the R progra...
# 10  pandas is the world's most popular Python libr...
# 11  This is your chance to dive into the worlds of...
# 12  The decisions we make in life are guided by ou...
# 13  Data scientists can experience huge benefits b...
# 14  So you've learned how to aggregate and join da...
# 15  A good proportion of the data out there in the...
# 16  Generalized Additive Models are a powerful too...
# 17  Bayesian data analysis is an approach to stati...
# 18  This is an introduction to the programming lan...
# 19  Data science isn't just for predicting ad-clic...
# 20  Often in data science, you'll encounter fascin...
# 21  A vital component of data science involves acq...
# 22  R is a great language for data science, but so...
# 23  Kaggle is the most famous platform for Data Sc...
# 24  Communication is a key part of the data scienc...
# 25  One of the biggest challenges when studying da...
# 26  Cluster analysis is a powerful toolkit in the ...
# 27  Great data visualization is the cornerstone of...
# 28  Now that you're proficient in many areas of da...
# 29  If you want to apply your new 'Python for Data...
# 30  Time series data is omnipresent in the field o...
# 31  Character strings can turn up in all stages of...
# 32  Python is now well established as a major plat...
# 33                                     No Description
# 34  Now that you've learned the basics of SQL in o...
# 35  Python is a versatile programming language tha...
# 36  This course will help you take your data visua...
# 37  pandas DataFrames are the most widely used in-...
# 38  Once you've started learning tools for buildin...
# 39  The ability to build tools capable of retrievi...
# 40  Do you want to make beautiful, informative vis...
# 41  Bokeh is an interactive data visualization lib...
# 42  If you have experience with SAS and want to le...
# 43  As with any fundamentals course, Introduction ...
# 44  Deploying machine learning models in productio...
# 45  Linear regression serves as a workhorse of sta...
# 46  Machine learning is the study and application ...
# 47  Do you know the basics of supervised learning ...
# 48  Being able to write your own functions makes y...
# 49                                     No Description

# %%
chapter_names = []
for course_link in links_dc:
    course_html = requests.get(course_link)
    course_html = course_html.text
    course_soup = BeautifulSoup(course_html, 'lxml')
    a = list(set(course_soup.find_all('h4',{'class':'chapter__title'})))
    for b in a:
        chapter_names.append(b.text.strip())

# %%
chapter_descs = []
for course_link in links_dc:
    course_html = requests.get(course_link)
    course_html = course_html.text
    course_soup = BeautifulSoup(course_html, 'lxml')
    a = list(set(course_soup.find_all('p',{'class':'chapter__description dc-u-fxi-fg-1 dc-u-pr-24 dc-u-pl-24 dc-u-mb-18'})))
    for b in a:
        try:
            chapter_descs.append(b.text.strip())
        except AttributeError:
            chapter_descs.append('No Description for This Chapter')

# %%
df_dc = pd.DataFrame({'Chapter Names':chapter_names,'Chapter Description':chapter_descs})
df_dc
# Out:
#                                    Chapter Names  \
# 0                   Introduction to Data Science
# 1                    Data Collection and Storage
# 2    Preparation, Exploration, and Visualization
# 3                 Experimentation and Prediction
# 4                   Introduction to Data Science
# ..                                           ...
# 192                  Classification with XGBoost
# 193                      How to write a function
# 194                   Case study on grain yields
# 195                      Return values and scope
# 196                          All about arguments
#
#                                    Chapter Description
# 0    Data preparation is fundamental: data scientis...
# 1    We'll start the course by defining what data s...
# 2    In this final chapter, we'll discuss experimen...
# 3    Now that we understand the data science workfl...
# 4    We'll start the course by defining what data s...
# ..                                                 ...
# 192  Take your XGBoost skills to the next level by ...
# 193  Learn how to return early from a function, how...
# 194  Apply your function writing skills to a case s...
# 195  Learn why writing your own functions is useful...
# 196  Learn how to set defaults for arguments, how t...
#
# [197 rows x 2 columns]

# %%
df_dc.insert(0, 'Course Names', '')

# %%
a = 0
for i in range(len(df_dc_courses)):
    num = df_dc_courses.iloc[i,1]
    df_dc.iloc[a:a+num,0] = df_dc_courses.iloc[i,0]
    a += num

# %%
df_dc.insert(1,'Course Descriptions','')

# %%
b = 0
for i in range(len(df_dc_courses)):
    num =  df_dc_courses.iloc[i,1]
    df_dc.iloc[b:b+num,1] = df_dc_courses.iloc[i,2]
    b += num

# %%
df_dc
# Out:
#                                Course Names  \
# 0                 Data Science for Everyone
# 1                 Data Science for Everyone
# 2                 Data Science for Everyone
# 3                 Data Science for Everyone
# 4                 Data Science for Business
# ..                                      ...
# 192  Extreme Gradient Boosting with XGBoost
# 193  Introduction to Writing Functions in R
# 194  Introduction to Writing Functions in R
# 195  Introduction to Writing Functions in R
# 196  Introduction to Writing Functions in R
#
#                                    Course Descriptions  \
# 0    What is data science, why is it so popular, an...
# 1    What is data science, why is it so popular, an...
# 2    What is data science, why is it so popular, an...
# 3    What is data science, why is it so popular, an...
# 4    What is data science and how can you use it to...
# ..                                                 ...
# 192  Do you know the basics of supervised learning ...
# 193  Being able to write your own functions makes y...
# 194  Being able to write your own functions makes y...
# 195  Being able to write your own functions makes y...
# 196  Being able to write your own functions makes y...
#
#                                    Chapter Names  \
# 0                   Introduction to Data Science
# 1                    Data Collection and Storage
# 2    Preparation, Exploration, and Visualization
# 3                 Experimentation and Prediction
# 4                   Introduction to Data Science
# ..                                           ...
# 192                  Classification with XGBoost
# 193                      How to write a function
# 194                   Case study on grain yields
# 195                      Return values and scope
# 196                          All about arguments
#
#                                    Chapter Description
# 0    Data preparation is fundamental: data scientis...
# 1    We'll start the course by defining what data s...
# 2    In this final chapter, we'll discuss experimen...
# 3    Now that we understand the data science workfl...
# 4    We'll start the course by defining what data s...
# ..                                                 ...
# 192  Take your XGBoost skills to the next level by ...
# 193  Learn how to return early from a function, how...
# 194  Apply your function writing skills to a case s...
# 195  Learn why writing your own functions is useful...
# 196  Learn how to set defaults for arguments, how t...
#
# [197 rows x 4 columns]

# %%
df_dc.to_csv('datacamp.csv')
